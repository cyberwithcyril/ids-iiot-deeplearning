# %%
import pandas as pd

df_new = pd.read_csv(r"C:\Users\CyrilCorp\Desktop\MERGED_CSV\Merged01.csv", nrows=5)
print(f"Shape: {df_new.shape}")
print(f"\nColumns ({len(df_new.columns)}):")
print(df_new.columns.tolist())
print(f"\nLabel values: {df_new['label'].unique() if 'label' in df_new.columns else df_new['Label'].unique()}")

# %%
import pandas as pd

df_2017 = pd.read_csv(r"C:\Users\CyrilCorp\Desktop\MachineLearningCVE\Monday-WorkingHours.pcap_ISCX.csv", nrows=5)
print(f"Shape: {df_2017.shape}")
print(f"\nColumns ({len(df_2017.columns)}):")
print(df_2017.columns.tolist())

# %%
# ── Dataset Merge Investigation ───────────────────────────────────────────
# Investigated two candidate datasets for merging with DataSense CIC IIoT 2025:
#
# 1. CIC-IoT-2023 (UNB) — 39 features
#    Issue: Different naming convention, different aggregation logic
#
# 2. CIC-IDS-2017 (UNB) — 79 features
#    Issue: Separates fwd/bwd traffic; DataSense uses combined flow features
#
# Conclusion: Direct merge not viable without re-extracting from raw PCAPs
# using a unified CICFlowMeter configuration. Treating DataSense 2025 as
# the sole dataset for this study. Cross-dataset evaluation is noted as
# future work.

# %%
import joblib
import os

# Check what's actually in the data folder
data_path = r"/data"
print(os.listdir(data_path))

# %%
print(os.listdir(r"/data/processed"))

# %%
df = pd.read_csv(r"/data/processed/cleaned_eda.csv", nrows=2)
print(df.columns.tolist())

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\CyrilCorp\Desktop\CICOutput\Friday-WorkingHours.pcap_Flow.csv", nrows=5)
print(f"Columns ({len(df.columns)}):")
print(df.columns.tolist())

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\CyrilCorp\Desktop\Edge-IIoTset dataset\Selected dataset for ML and DL\DNN-EdgeIIoT-dataset.csv", nrows=5, low_memory=False)
print(f"Shape: {df.shape}")
print(f"\nColumns ({len(df.columns)}):")
print(df.columns.tolist())
print(f"\nAttack types:")
print(df['Attack_type'].value_counts())

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\CyrilCorp\Desktop\Benign_train.pcap.csv", nrows=5)
print(f"Shape: {df.shape}")
print(f"Columns ({len(df.columns)}):")
print(df.columns.tolist())

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

RESULTS = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\results"
plt.style.use('dark_background')

models = ['XGBoost', 'Random\nForest', 'MLP', '1D-CNN', 'BiLSTM', 'Logistic\nRegression']
f1     = [0.9679, 0.9592, 0.9554, 0.9537, 0.9473, 0.8933]
auc    = [0.9914, 0.9866, 0.9875, 0.9867, 0.9815, 0.9505]

x = np.arange(len(models))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 7))
fig.patch.set_facecolor('#1a0a2e')
ax.set_facecolor('#1a0a2e')

bars1 = ax.bar(x - width/2, f1,  width, label='F1-Score',  color='#7030A0', alpha=0.9, zorder=3)
bars2 = ax.bar(x + width/2, auc, width, label='AUC-ROC', color='#FFC446', alpha=0.9, zorder=3)

ax.set_ylim(0.88, 1.005)
ax.set_xticks(x)
ax.set_xticklabels(models, fontsize=13, color='white')
ax.set_ylabel('Score', fontsize=14, color='white')
ax.set_title('Model Performance — DataSense CIC IIoT 2025', fontsize=16, color='white', pad=15)
ax.tick_params(colors='white')
ax.spines['bottom'].set_color('#7030A0')
ax.spines['left'].set_color('#7030A0')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.grid(True, color='#3a1a5a', zorder=0)
ax.set_axisbelow(True)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
            f'{bar.get_height():.4f}', ha='center', va='bottom', fontsize=9, color='#7030A0')
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
            f'{bar.get_height():.4f}', ha='center', va='bottom', fontsize=9, color='#FFC446')

ax.legend(fontsize=13, facecolor='#1a0a2e', edgecolor='#7030A0', labelcolor='white')
plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "../results/chart_iiot_model_comparison.png"), dpi=150, bbox_inches='tight', facecolor='#1a0a2e')
plt.show()
print("Saved: chart_iiot_model_comparison.png")

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

RESULTS = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\results"
plt.style.use('dark_background')

models = ['XGBoost', 'Random\nForest', 'MLP', '1D-CNN', 'BiLSTM', 'Logistic\nRegression']
f1     = [0.9679, 0.9592, 0.9554, 0.9537, 0.9473, 0.8933]
auc    = [0.9914, 0.9866, 0.9875, 0.9867, 0.9815, 0.9505]

x = np.arange(len(models))
width = 0.35

fig, ax = plt.subplots(figsize=(14, 7))
fig.patch.set_facecolor('#1a0a2e')
ax.set_facecolor('#1a0a2e')

bars1 = ax.bar(x - width/2, f1,  width, label='F1-Score',  color='#7030A0', alpha=0.9, zorder=3)
bars2 = ax.bar(x + width/2, auc, width, label='AUC-ROC', color='#FFC446', alpha=0.9, zorder=3)

ax.set_ylim(0.88, 1.005)
ax.set_xticks(x)
ax.set_xticklabels(models, fontsize=13, color='white')
ax.set_ylabel('Score', fontsize=14, color='white')
ax.set_title('Model Performance — DataSense CIC IIoT 2025', fontsize=16, color='white', pad=15)
ax.tick_params(colors='white')
ax.spines['bottom'].set_color('#7030A0')
ax.spines['left'].set_color('#7030A0')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.grid(True, color='#3a1a5a', zorder=0)
ax.set_axisbelow(True)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
            f'{bar.get_height():.4f}', ha='center', va='bottom', fontsize=9, color='#7030A0')
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
            f'{bar.get_height():.4f}', ha='center', va='bottom', fontsize=9, color='#FFC446')

ax.legend(fontsize=13, facecolor='#1a0a2e', edgecolor='#7030A0', labelcolor='white')
plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "../results/chart_iiot_model_comparison.png"), dpi=150, bbox_inches='tight', facecolor='#1a0a2e')
plt.show()
print("Saved: chart_iiot_model_comparison.png")

# %%
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import os

PROCESSED = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\data\processed"
RESULTS   = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\results"
MODELS    = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\models"

# Load
xgb = joblib.load(os.path.join(MODELS, "xgboost.pkl"))
X_test = np.load(os.path.join(PROCESSED, "X_test.npy"))

# Get feature names from cleaned EDA CSV
df = pd.read_csv(os.path.join(PROCESSED, "cleaned_eda.csv"), nrows=1)
feature_names = [c for c in df.columns if c != 'label']
print(f"Features: {len(feature_names)}")
print(f"X_test shape: {X_test.shape}")

X_test_df = pd.DataFrame(X_test, columns=feature_names)

# Sample
np.random.seed(42)
sample_idx = np.random.choice(len(X_test_df), 500, replace=False)
X_sample = X_test_df.iloc[sample_idx]

# SHAP
explainer = shap.TreeExplainer(xgb)
shap_values = explainer.shap_values(X_sample)

# ── Beeswarm with purple labels ───────────────────────────────────────────
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(12, 8))
fig.patch.set_facecolor('#1a0a2e')
ax.set_facecolor('#1a0a2e')

shap.summary_plot(
    shap_values, X_sample,
    feature_names=feature_names,
    max_display=10,
    show=False,
    plot_size=None
)

ax = plt.gca()
ax.set_facecolor('#1a0a2e')
for label in ax.get_yticklabels():
    label.set_color('#CC99FF')
    label.set_fontsize(12)
for label in ax.get_xticklabels():
    label.set_color('white')
    label.set_fontsize(10)

ax.xaxis.label.set_color('white')
ax.xaxis.label.set_fontsize(12)
ax.title.set_color('white')
ax.title.set_fontsize(14)
ax.title.set_text('SHAP Feature Importance — XGBoost (Top 10)')

fig = plt.gcf()
fig.patch.set_facecolor('#1a0a2e')
for ax_obj in fig.get_axes():
    ax_obj.set_facecolor('#1a0a2e')
    for label in ax_obj.get_yticklabels():
        label.set_color('white')
    if hasattr(ax_obj.yaxis, 'label'):
        ax_obj.yaxis.label.set_color('white')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS, "shap_beeswarm_purple.png"),
            dpi=150, bbox_inches='tight', facecolor='#1a0a2e')
plt.show()
print("Saved: shap_beeswarm_purple.png")
# Out:
# Features: 50
# X_test shape: (6759, 50)
# C:\Users\CyrilCorp\AppData\Local\Temp\ipykernel_16972\3458463773.py:39: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# Saved: shap_beeswarm_purple.png

# %%
import os
PROCESSED = r"C:\Users\CyrilCorp\PyCharmMiscProject\ids-iiot-deeplearning\data\processed"
print(os.listdir(PROCESSED))
# Out:
# ['class_weights.npy', 'cleaned_eda.csv', 'scaler.pkl', 'X_test.npy', 'X_train.npy', 'X_val.npy', 'y_test.npy', 'y_train.npy', 'y_val.npy']
