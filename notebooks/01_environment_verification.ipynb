# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sklearn
import matplotlib
import shap

print(f"TensorFlow:   {tf.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
print(f"Pandas:       {pd.__version__}")

# Load both files
attack = pd.read_csv("data/raw/attack_samples_5sec.csv")
benign = pd.read_csv("data/raw/benign_samples_5sec.csv")

print(f"\nAttack shape:  {attack.shape}")
print(f"Benign shape:  {benign.shape}")
print(f"\nColumns:\n{list(attack.columns)}")
print(f"\nDtypes:\n{attack.dtypes.value_counts()}")
print(f"\nMissing values (attack): {attack.isnull().sum().sum()}")
print(f"Missing values (benign): {benign.isnull().sum().sum()}")
# Out:
# TensorFlow:   2.21.0
# Scikit-learn: 1.8.0
# Pandas:       3.0.1
#
# Attack shape:  (17695, 94)
# Benign shape:  (27360, 94)
#
# Columns:
# ...
